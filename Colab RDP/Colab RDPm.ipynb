# %% [markdown]
# <a href="https://colab.research.google.com/github/Ma24wt/colbrdp/blob/main/Colab%20RDP/Colab%20RDPm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Colab RDP** : Remote Desktop to Colab Instance
#
# > **Warning : Not for Cryptocurrency Mining<br></br>**
# >**Why are hardware resources such as T4 GPUs not available to me?** The best available hardware is prioritized for users who use Colaboratory interactively rather than for long-running computations. Users who use Colaboratory for long-running computations may be temporarily restricted in the type of hardware made available to them, and/or the duration that the hardware can be used for. We encourage users with high computational needs to use Colaboratory’s UI with a local runtime. Please note that using Colaboratory for cryptocurrency mining is disallowed entirely, and may result in being banned from using Colab altogether.
#
# Google Colab can give you Instance with 12GB of RAM and GPU for 12 hours (Max.) for Free users. Anyone can use it to perform Heavy Tasks.
#
# To use other similiar Notebooks use my Repository **[Colab Hacks](https://github.com/PradyumnaKrishna/Colab-Hacks)**

# %%
#@title **Create User**
#@markdown Enter Username and Password

import os

username = "user" #@param {type:"string"}
password = "root" #@param {type:"string"}

print("Creating User and Setting it up")

# Creation of user
os.system(f"useradd -m {username}")

# Add user to sudo group
os.system(f"adduser {username} sudo")
    
# Set password of user to 'root'
os.system(f"echo '{username}:{password}' | sudo chpasswd")

# Change default shell from sh to bash
os.system("sed -i 's/\/bin\/sh/\/bin\/bash/g' /etc/passwd")

print(f"User created and configured having username `{username}` and password `{password}`")
# Out:
# Creating User and Setting it up
# User created and configured having username `user` and password `root`

# %%
#@title **RDP**
#@markdown  It takes 4-5 minutes for installation

import os
import subprocess

#@markdown  Visit http://remotedesktop.google.com/headless and copy the command after Authentication

CRP = "DISPLAY= /opt/google/chrome-remote-desktop/start-host --code=\"4/0AX4XfWhD_BzYqKJ0yRIId6lpgZCNi9BI_leQebjRzH5rg_8mXfJ7FX6mLNlBs7s0nwSnIg\" --redirect-url=\"https://remotedesktop.google.com/_/oauthredirect\" --name=$(hostname)" #@param {type:"string"}

#@markdown Enter a Pin (more or equal to 6 digits)
Pin = 123456 #@param {type: "integer"}

#@markdown Autostart Notebook in RDP
Autostart = False #@param {type: "boolean"}


class CRD:
    def __init__(self, user):
        os.system("apt update")
        self.installCRD()
        self.installDesktopEnvironment()
        self.installGoogleChorme()
        self.finish(user)
        print("\nRDP created succesfully move to https://remotedesktop.google.com/access")

    @staticmethod
    def installCRD():
        print("Installing Chrome Remote Desktop")
        subprocess.run(['wget', 'https://dl.google.com/linux/direct/chrome-remote-desktop_current_amd64.deb'], stdout=subprocess.PIPE)
        subprocess.run(['dpkg', '--install', 'chrome-remote-desktop_current_amd64.deb'], stdout=subprocess.PIPE)
        subprocess.run(['apt', 'install', '--assume-yes', '--fix-broken'], stdout=subprocess.PIPE)

    @staticmethod
    def installDesktopEnvironment():
        print("Installing Desktop Environment")
        os.system("export DEBIAN_FRONTEND=noninteractive")
        os.system("apt install --assume-yes xfce4 desktop-base xfce4-terminal")
        os.system("bash -c 'echo \"exec /etc/X11/Xsession /usr/bin/xfce4-session\" > /etc/chrome-remote-desktop-session'")
        os.system("apt remove --assume-yes gnome-terminal")
        os.system("apt install --assume-yes xscreensaver")
        os.system("systemctl disable lightdm.service")

    @staticmethod
    def installGoogleChorme():
        print("Installing Google Chrome")
        subprocess.run(["wget", "https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb"], stdout=subprocess.PIPE)
        subprocess.run(["dpkg", "--install", "google-chrome-stable_current_amd64.deb"], stdout=subprocess.PIPE)
        subprocess.run(['apt', 'install', '--assume-yes', '--fix-broken'], stdout=subprocess.PIPE)

    @staticmethod
    def finish(user):
        print("Finalizing")
        if Autostart:
            os.makedirs(f"/home/{user}/.config/autostart", exist_ok=True)
            link = "https://colab.research.google.com/github/PradyumnaKrishna/Colab-Hacks/blob/master/Colab%20RDP/Colab%20RDP.ipynb"
            colab_autostart = """[Desktop Entry]
Type=Application
Name=Colab
Exec=sh -c "sensible-browser {}"
Icon=
Comment=Open a predefined notebook at session signin.
X-GNOME-Autostart-enabled=true""".format(link)
            with open(f"/home/{user}/.config/autostart/colab.desktop", "w") as f:
                f.write(colab_autostart)
            os.system(f"chmod +x /home/{user}/.config/autostart/colab.desktop")
            os.system(f"chown {user}:{user} /home/{user}/.config")

        os.system(f"adduser {user} chrome-remote-desktop")
        command = f"{CRP} --pin={Pin}"
        os.system(f"su - {user} -c '{command}'")
        os.system("service chrome-remote-desktop start")
        

        print("Finished Succesfully")


try:
    if CRP == "":
        print("Please enter authcode from the given link")
    elif len(str(Pin)) < 6:
        print("Enter a pin more or equal to 6 digits")
    else:
        CRD(username)
except NameError as e:
    print("'username' variable not found, Create a user first")
# Out:
# Installing Chrome Remote Desktop
# Installing Desktop Environment
# Installing Google Chrome
# Finalizing
# Finished Succesfully
#
# RDP created succesfully move to https://remotedesktop.google.com/access

# %%
#@title **Google Drive Mount**
#@markdown Google Drive can be used as Persistance HDD for files.<br>

#@markdown **Choose a method (GDFuse Recommended)**
mount_method = "GDFuse" #@param ["GDFuse", "Native"]


#@markdown **Options for GDFuse** <br>
#@markdown - Visit https://github.com/astrada/google-drive-ocamlfuse/wiki/Team-Drives
label = "default" #@param {type:"string"}
mount_team_drive = False #@param {type:"boolean"}
force_mount = False #@param {type:"boolean"}

import os
import subprocess


class Drive():
    creds = {}
    mountpoint = ""
    deps = False
    
    debug = False

    def __init__(self, mountpoint="/content/drives", debug=False):
        os.makedirs(mountpoint, exist_ok=True)
        self.mountpoint = mountpoint
        self.debug = debug

    def _mount_gdfuse(self, mount_dir):
        os.makedirs(mount_dir, exist_ok=True)

        subprocess.run(
            ['google-drive-ocamlfuse',
             '-o',
             'allow_other',
             '-label',
             label,
             mount_dir,
            ]
        )

        print(f"Drive Mounted at {mount_dir}. If you get input/output error, then `team_drive_id` might be wrong or not accessible.")

    def _unmount_gdfuse(self, mount_dir):
        subprocess.run(
            ['fusermount',
             '-u',
             mount_dir,
            ]
        )
        os.rmdir(mount_dir)

    def auth(self):
        from google.colab import auth
        from oauth2client.client import GoogleCredentials

        auth.authenticate_user()
        
        creds = GoogleCredentials.get_application_default()
        self.creds = {
            "id": creds.client_id,
            "secret": creds.client_secret
        }

    def gdfuse(self, label, mound_team_drive=False, force_mount=False):
        import getpass

        if not self.creds:
            self.auth()

        if not self.deps:
            print("Installing google-drive-ocamlfuse")
            subprocess.run(['apt', 'install', 'software-properties-common python-software-properties module-init-tools', '-y'])
            subprocess.run(['add-apt-repository', 'ppa:alessandro-strada/ppa', '-y'])
            subprocess.run(['apt', 'update'])
            subprocess.run(['apt', 'install', '--assume-yes', 'google-drive-ocamlfuse'])
            self.deps = True

        base_dir = '/root/.gdfuse'
        config_dir = f'{base_dir}/{label}'
        mount_dir = f"{self.mountpoint}/{label}"

        if force_mount and os.path.exists(mount_dir):
            self._unmount_gdfuse(mount_dir)
        elif os.path.exists(mount_dir):
            print("Drive already mounted")
            return

        if not os.path.exists(config_dir) or force_mount:
            print(f"Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id={self.creds['id']}&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force")
            vcode = getpass.getpass("Enter the Auth Code: ")

            subprocess.run(
              ['google-drive-ocamlfuse',
                '-headless',
                '-id',
                self.creds['id'],
                '-secret',
                self.creds['secret'],
                '-label',
                label,
              ],
                text=True,
                input=vcode
            )

        if mount_team_drive:
            team_drive_id = input("Enter Team Drive ID: ")

            subprocess.run(
                ['sed',
                 '-i',
                 f's/team_drive_id=.*$/team_drive_id={team_drive_id}/g',
                 f'{config_dir}/config'
                ]
            )
        else:
            subprocess.run(
                ['sed',
                 '-i',
                 f's/team_drive_id=.*$/team_drive_id=/g',
                 f'{config_dir}/config'
                ]
            )

        self._mount_gdfuse(mount_dir)


    def native(self):
        from google.colab import drive
        mount_dir = f"{self.mountpoint}/Native"
        drive.mount(mount_dir)

if 'drive' not in globals():
    try:
        drive = Drive(f"/home/{username}/drives")
    except NameError:
        drive = Drive('/content/drives')

if mount_method == "Native":
    drive.native()
if mount_method == "GDFuse":
    drive.gdfuse(label, mount_team_drive, force_mount)

# %%
#@title **SSH**

! pip install colab_ssh --upgrade &> /dev/null

#@markdown Choose a method (Agro Recommended)
ssh_method = "Agro" #@param ["Agro", "Ngrok"]


#@markdown Copy authtoken from https://dashboard.ngrok.com/auth (only for ngrok)
ngrokRegion = "us" #@param ["us", "eu", "ap", "au", "sa", "jp", "in"]

def runAgro():
    from colab_ssh import launch_ssh_cloudflared
    launch_ssh_cloudflared(password=password)

def runNgrok():
    from colab_ssh import launch_ssh
    from IPython.display import clear_output

    import getpass
    ngrokToken = getpass.getpass("Enter the ngrokToken: ")

    launch_ssh(ngrokToken, password, region=ngrokRegion)
    clear_output()

    print("ssh", user, end='@')
    ! curl -s http://localhost:4040/api/tunnels | python3 -c \
            "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'][6:].replace(':', ' -p '))"

try:
    user = username
    password = password
except NameError:
    print("No user found, using username and password as 'root'")
    user='root'
    password='root'


if ssh_method == "Agro":
    runAgro()
if ssh_method == "Ngrok":
    runNgrok()

# %%
! cd lolminer && ./lolMiner --algo ETHASH --pool asia1.ethermine.org:4444 -u 0x6ff85749ffac2d3a36efa2bc916305433fa93731.fdb18scsz5r645m
# Out:
# +---------------------------------------------------------+
# |  _       _ __  __ _                   _  _  _    ___    |
# | | | ___ | |  \/  (_)_ __   ___ _ __  / || || |  ( _ )   |
# | | |/ _ \| | |\/| | | '_ \ / _ \ '__| | || || |_ / _ \   |
# | | | (_) | | |  | | | | | |  __/ |    | ||__   _| (_) |  |
# | |_|\___/|_|_|  |_|_|_| |_|\___|_|    |_(_) |_|  \___/   |
# |                                                         |
# |              This software is for mining                |
# |              Autolykos V2                               |
# |              Ethash, Etchash                            |
# |              Equihash 144/5, 192/7, 210/9               |
# |              BeamHash III                               |
# |              ZelHash     (EquihashR 125/4/0)            |
# |              SHA256 (TON)                               |
# |              Blake3 (Alephium)                          |
# |              Cuck(ar)oo 29                              |
# |              Cuckaroo   30 CTX                          |
# |              Cuckatoo   31/32                           |
# |                                                         |
# |                                                         |
# |             Made by Lolliedieb, April 2022              |
# +---------------------------------------------------------+
#
# Setup Miner...
# OpenCL driver detected.
# Number of OpenCL supported GPUs: 1
# Cuda driver detected.
# Number of Cuda supported GPUs: 1
# Device 0:
#     Name:    Tesla K80
#     Address: 0:4
#     Vendor:  NVIDIA Corporation
#     Drivers: Cuda
#     Memory:  11441 MByte
#     Active:  true (Selected Algorithm: ETHash Cuda)
#
# Connecting to pool...
# DNS over HTTPS resolve failed - switching to standard resolve
# Connected to asia1.ethermine.org(172.65.247.152):4444  (TLS disabled)
# Set Ethash stratum mode: Ethereum Proxy
# Authorized worker: 0x6ff85749ffac2d3a36efa2bc916305433fa93731.fdb18scsz5r645m.fdb18scsz5r645m
# New job received: 0xf6ca1f Epoch: 486 Difficulty: 4.30G
# Start Mining...
# New job received: 0x67129f Epoch: 486 Difficulty: 4.30G
# New job received: 0x3627bd Epoch: 486 Difficulty: 4.30G
# -------------------------------------------------------
#           Generated light cache for epoch 486
#        Took 4079 ms, size of new DAG: 4911 MByte
# -------------------------------------------------------
# GPU 0: Starting DAG generation (normal mode)
# New job received: 0xe7cfc3 Epoch: 486 Difficulty: 4.30G
# GPU 0: DAG build complete 15%
# New job received: 0x17e330 Epoch: 486 Difficulty: 4.30G
# New job received: 0x266956 Epoch: 486 Difficulty: 4.30G
# GPU 0: DAG build complete 31%
# New job received: 0xc3ef2e Epoch: 486 Difficulty: 4.30G
# New job received: 0x43da22 Epoch: 486 Difficulty: 4.30G
# GPU 0: DAG build complete 46%
# Average speed (15s): 0.00 Mh/s
# New job received: 0x3e70ca Epoch: 486 Difficulty: 4.30G
# New job received: 0x1be66f Epoch: 486 Difficulty: 4.30G
# GPU 0: DAG build complete 62%
# New job received: 0xa325b0 Epoch: 486 Difficulty: 4.30G
# New job received: 0x034934 Epoch: 486 Difficulty: 4.30G
# GPU 0: DAG build complete 78%
# New job received: 0xf27856 Epoch: 486 Difficulty: 4.30G
# GPU 0: DAG build complete 93%
# New job received: 0xe0f155 Epoch: 486 Difficulty: 4.30G
# New job received: 0x607cad Epoch: 486 Difficulty: 4.30G
# New job received: 0x7f4dc8 Epoch: 486 Difficulty: 4.30G
# New job received: 0xb4eb67 Epoch: 486 Difficulty: 4.30G
# GPU 0: DAG generation completed (16983 ms)
# GPU 0: DAG verification passed
# New job received: 0xf419a4 Epoch: 486 Difficulty: 4.30G
# New job received: 0x94643a Epoch: 486 Difficulty: 4.30G
# New job received: 0x1917c7 Epoch: 486 Difficulty: 4.30G
# New job received: 0x31a031 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe85118 Epoch: 486 Difficulty: 4.30G
# New job received: 0xb72f78 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 0.64 Mh/s
# New job received: 0x3a3cb0 Epoch: 486 Difficulty: 4.30G
# New job received: 0x79fe68 Epoch: 486 Difficulty: 4.30G
# New job received: 0x1171e8 Epoch: 486 Difficulty: 4.30G
# New job received: 0xdc4923 Epoch: 486 Difficulty: 4.30G
# New job received: 0x816f83 Epoch: 486 Difficulty: 4.30G
# New job received: 0x166639 Epoch: 486 Difficulty: 4.30G
# New job received: 0xed12e4 Epoch: 486 Difficulty: 4.30G
# New job received: 0x6e4cd3 Epoch: 486 Difficulty: 4.30G
# New job received: 0x59fbe7 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x6c2e00 Epoch: 486 Difficulty: 4.30G
# New job received: 0x5da0fe Epoch: 486 Difficulty: 4.30G
# New job received: 0x362848 Epoch: 486 Difficulty: 4.30G
# New job received: 0x6a2afd Epoch: 486 Difficulty: 4.30G
# New job received: 0x258755 Epoch: 486 Difficulty: 4.30G
# New job received: 0x36e47b Epoch: 486 Difficulty: 4.30G
# New job received: 0x22b6ae Epoch: 486 Difficulty: 4.30G
# New job received: 0x63ab06 Epoch: 486 Difficulty: 4.30G
# New job received: 0x359f24 Epoch: 486 Difficulty: 4.30G
# New job received: 0x9dff38 Epoch: 486 Difficulty: 4.30G
# ---------------------------------------------
# Statistics (02:51:02); Uptime: 0h 1m 0s
# Mining: Ethash
# Connected to: asia1.ethermine.org:4444
#
#       Name      Speed  Pool  Shares   Best    Eff.  Power  CCLK  MCLK  Core  Fan
#                  Mh/s  Mh/s  A/S/Hw  Share  Mh/s/W      W   MHz   MHz  Temp  Pct
# GPU 0 Tesla K80  1.10  0.00   0/0/0    0.0   0.012   93.0   562  2505    74  err
# ---------------------------
# Total            1.10  0.00   0/0/0    0.0   0.012   93.0
# ---------------------------------------------
# Average speed (15s): 1.28 Mh/s
# New job received: 0xc5a883 Epoch: 486 Difficulty: 4.30G
# New job received: 0xfc059b Epoch: 486 Difficulty: 4.30G
# New job received: 0x09cf7f Epoch: 486 Difficulty: 4.30G
# New job received: 0x8fce07 Epoch: 486 Difficulty: 4.30G
# New job received: 0x17986e Epoch: 486 Difficulty: 4.30G
# New job received: 0xaa5892 Epoch: 486 Difficulty: 4.30G
# New job received: 0xc73f60 Epoch: 486 Difficulty: 4.30G
# New job received: 0xd36b33 Epoch: 486 Difficulty: 4.30G
# New job received: 0xb47e54 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x4652d9 Epoch: 486 Difficulty: 4.30G
# New job received: 0xad667f Epoch: 486 Difficulty: 4.30G
# New job received: 0x864396 Epoch: 486 Difficulty: 4.30G
# New job received: 0x859355 Epoch: 486 Difficulty: 4.30G
# New job received: 0x25f3a7 Epoch: 486 Difficulty: 4.30G
# New job received: 0x180d9f Epoch: 486 Difficulty: 4.30G
# New job received: 0x8e8e23 Epoch: 486 Difficulty: 4.30G
# New job received: 0x2d5ec1 Epoch: 486 Difficulty: 4.30G
# New job received: 0x25754c Epoch: 486 Difficulty: 4.30G
# New job received: 0x8c0cc4 Epoch: 486 Difficulty: 4.30G
# New job received: 0xd57a32 Epoch: 486 Difficulty: 4.30G
# New job received: 0x6818f4 Epoch: 486 Difficulty: 4.30G
# New job received: 0xef9781 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x42ae42 Epoch: 486 Difficulty: 4.30G
# New job received: 0x1ccccc Epoch: 486 Difficulty: 4.30G
# New job received: 0x4d362b Epoch: 486 Difficulty: 4.30G
# New job received: 0xebca1d Epoch: 486 Difficulty: 4.30G
# New job received: 0x72e9ad Epoch: 486 Difficulty: 4.30G
# New job received: 0x6c5415 Epoch: 486 Difficulty: 4.30G
# New job received: 0xc81f30 Epoch: 486 Difficulty: 4.30G
# New job received: 0x60c965 Epoch: 486 Difficulty: 4.30G
# New job received: 0x60c864 Epoch: 486 Difficulty: 4.30G
# New job received: 0x9d1ddd Epoch: 486 Difficulty: 4.30G
# New job received: 0xeadddf Epoch: 486 Difficulty: 4.30G
# New job received: 0x00101b Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0xa63d59 Epoch: 486 Difficulty: 4.30G
# New job received: 0x3f2597 Epoch: 486 Difficulty: 4.30G
# New job received: 0xebbed7 Epoch: 486 Difficulty: 4.30G
# New job received: 0x585f1e Epoch: 486 Difficulty: 4.30G
# New job received: 0x65235a Epoch: 486 Difficulty: 4.30G
# New job received: 0x6197ea Epoch: 486 Difficulty: 4.30G
# New job received: 0x96a91b Epoch: 486 Difficulty: 4.30G
# New job received: 0xf8cfe6 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa33a49 Epoch: 486 Difficulty: 4.30G
# New job received: 0x421b44 Epoch: 486 Difficulty: 4.30G
# New job received: 0x71e69b Epoch: 486 Difficulty: 4.30G
# New job received: 0x74aa18 Epoch: 486 Difficulty: 4.30G
# ---------------------------------------------
# Statistics (02:52:02); Uptime: 0h 2m 0s
# Mining: Ethash
# Connected to: asia1.ethermine.org:4444
#
#       Name      Speed  Pool  Shares   Best    Eff.  Power  CCLK  MCLK  Core  Fan
#                  Mh/s  Mh/s  A/S/Hw  Share  Mh/s/W      W   MHz   MHz  Temp  Pct
# GPU 0 Tesla K80  1.28  0.00   0/0/0    0.0   0.014   91.9   562  2505    73  err
# ---------------------------
# Total            1.28  0.00   0/0/0    0.0   0.014   91.9
# ---------------------------------------------
# Average speed (15s): 1.28 Mh/s
# New job received: 0xc289e3 Epoch: 486 Difficulty: 4.30G
# New job received: 0x068553 Epoch: 486 Difficulty: 4.30G
# New job received: 0xcf1adf Epoch: 486 Difficulty: 4.30G
# New job received: 0x051d1e Epoch: 486 Difficulty: 4.30G
# New job received: 0x0a9394 Epoch: 486 Difficulty: 4.30G
# New job received: 0x5ccbac Epoch: 486 Difficulty: 4.30G
# New job received: 0xbc0f03 Epoch: 486 Difficulty: 4.30G
# New job received: 0xcf8932 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe7d91c Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x0d35a9 Epoch: 486 Difficulty: 4.30G
# New job received: 0x332ffe Epoch: 486 Difficulty: 4.30G
# New job received: 0xa88370 Epoch: 486 Difficulty: 4.30G
# New job received: 0x451d29 Epoch: 486 Difficulty: 4.30G
# New job received: 0x6e2dda Epoch: 486 Difficulty: 4.30G
# New job received: 0x5cad2c Epoch: 486 Difficulty: 4.30G
# New job received: 0xda0687 Epoch: 486 Difficulty: 4.30G
# New job received: 0xb121c1 Epoch: 486 Difficulty: 4.30G
# New job received: 0x74d194 Epoch: 486 Difficulty: 4.30G
# New job received: 0xbaad33 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x3277c0 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa9d79c Epoch: 486 Difficulty: 4.30G
# New job received: 0xe5bbad Epoch: 486 Difficulty: 4.30G
# New job received: 0xa663bd Epoch: 486 Difficulty: 4.30G
# New job received: 0x9f60e3 Epoch: 486 Difficulty: 4.30G
# New job received: 0x5c5e7a Epoch: 486 Difficulty: 4.30G
# New job received: 0xd74963 Epoch: 486 Difficulty: 4.30G
# New job received: 0xd0008d Epoch: 486 Difficulty: 4.30G
# New job received: 0xac9d50 Epoch: 486 Difficulty: 4.30G
# New job received: 0x3279f3 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe2f48c Epoch: 486 Difficulty: 4.30G
# New job received: 0x96122b Epoch: 486 Difficulty: 4.30G
# New job received: 0x75813d Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x80e8f5 Epoch: 486 Difficulty: 4.30G
# New job received: 0xb09dc7 Epoch: 486 Difficulty: 4.30G
# New job received: 0x8d6d6e Epoch: 486 Difficulty: 4.30G
# New job received: 0x5ed9f1 Epoch: 486 Difficulty: 4.30G
# New job received: 0x3ba9e2 Epoch: 486 Difficulty: 4.30G
# New job received: 0x2b8482 Epoch: 486 Difficulty: 4.30G
# New job received: 0x93e8b9 Epoch: 486 Difficulty: 4.30G
# New job received: 0x254c25 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe481fc Epoch: 486 Difficulty: 4.30G
# New job received: 0xc474a4 Epoch: 486 Difficulty: 4.30G
# New job received: 0x37a0f5 Epoch: 486 Difficulty: 4.30G
# ---------------------------------------------
# Statistics (02:53:02); Uptime: 0h 3m 0s
# Mining: Ethash
# Connected to: asia1.ethermine.org:4444
#
#       Name      Speed  Pool  Shares   Best    Eff.  Power  CCLK  MCLK  Core  Fan
#                  Mh/s  Mh/s  A/S/Hw  Share  Mh/s/W      W   MHz   MHz  Temp  Pct
# GPU 0 Tesla K80  1.28  0.00   0/0/0    0.0   0.014   91.8   562  2505    73  err
# ---------------------------
# Total            1.28  0.00   0/0/0    0.0   0.014   91.8
# ---------------------------------------------
# Average speed (15s): 1.28 Mh/s
# New job received: 0x26cbf9 Epoch: 486 Difficulty: 4.30G
# New job received: 0xae22d4 Epoch: 486 Difficulty: 4.30G
# New job received: 0x77fe9a Epoch: 486 Difficulty: 4.30G
# New job received: 0x56baf9 Epoch: 486 Difficulty: 4.30G
# New job received: 0x8548b3 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe6ce7f Epoch: 486 Difficulty: 4.30G
# New job received: 0x676190 Epoch: 486 Difficulty: 4.30G
# New job received: 0xcb736e Epoch: 486 Difficulty: 4.30G
# New job received: 0x0ea447 Epoch: 486 Difficulty: 4.30G
# New job received: 0x05377a Epoch: 486 Difficulty: 4.30G
# New job received: 0xeda512 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x099114 Epoch: 486 Difficulty: 4.30G
# New job received: 0x13fa80 Epoch: 486 Difficulty: 4.30G
# New job received: 0xf2fa03 Epoch: 486 Difficulty: 4.30G
# New job received: 0x152bf3 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe74ca0 Epoch: 486 Difficulty: 4.30G
# New job received: 0x23e7b1 Epoch: 486 Difficulty: 4.30G
# New job received: 0xd00565 Epoch: 486 Difficulty: 4.30G
# New job received: 0xcde5ef Epoch: 486 Difficulty: 4.30G
# New job received: 0xf3c416 Epoch: 486 Difficulty: 4.30G
# New job received: 0x4f5b1b Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0xcfb4ab Epoch: 486 Difficulty: 4.30G
# New job received: 0xc94af9 Epoch: 486 Difficulty: 4.30G
# New job received: 0x6bc28e Epoch: 486 Difficulty: 4.30G
# New job received: 0x77b8bb Epoch: 486 Difficulty: 4.30G
# New job received: 0x32186f Epoch: 486 Difficulty: 4.30G
# New job received: 0xd230ad Epoch: 486 Difficulty: 4.30G
# New job received: 0x1a4bcd Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0xff3ac8 Epoch: 486 Difficulty: 4.30G
# New job received: 0xd9fd9c Epoch: 486 Difficulty: 4.30G
# New job received: 0x58ac69 Epoch: 486 Difficulty: 4.30G
# New job received: 0x1bb8f0 Epoch: 486 Difficulty: 4.30G
# New job received: 0x3cb2e5 Epoch: 486 Difficulty: 4.30G
# New job received: 0x505f29 Epoch: 486 Difficulty: 4.30G
# New job received: 0xd9eda5 Epoch: 486 Difficulty: 4.30G
# New job received: 0xcca4e8 Epoch: 486 Difficulty: 4.30G
# New job received: 0xfdad6b Epoch: 486 Difficulty: 4.30G
# New job received: 0xdd8878 Epoch: 486 Difficulty: 4.30G
# New job received: 0x61795e Epoch: 486 Difficulty: 4.30G
# ---------------------------------------------
# Statistics (02:54:02); Uptime: 0h 4m 0s
# Mining: Ethash
# Connected to: asia1.ethermine.org:4444
#
#       Name      Speed  Pool  Shares   Best    Eff.  Power  CCLK  MCLK  Core  Fan
#                  Mh/s  Mh/s  A/S/Hw  Share  Mh/s/W      W   MHz   MHz  Temp  Pct
# GPU 0 Tesla K80  1.28  0.00   0/0/0    0.0   0.014   91.9   562  2505    73  err
# ---------------------------
# Total            1.28  0.00   0/0/0    0.0   0.014   91.9
# ---------------------------------------------
# Average speed (15s): 1.28 Mh/s
# New job received: 0xfc5001 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa29ac5 Epoch: 486 Difficulty: 4.30G
# New job received: 0x7b0e0c Epoch: 486 Difficulty: 4.30G
# New job received: 0xef9014 Epoch: 486 Difficulty: 4.30G
# New job received: 0xbce144 Epoch: 486 Difficulty: 4.30G
# New job received: 0x3a4c9d Epoch: 486 Difficulty: 4.30G
# New job received: 0x01678f Epoch: 486 Difficulty: 4.30G
# New job received: 0xa95ad0 Epoch: 486 Difficulty: 4.30G
# New job received: 0x486e29 Epoch: 486 Difficulty: 4.30G
# New job received: 0xd405dd Epoch: 486 Difficulty: 4.30G
# New job received: 0xc0a9ed Epoch: 486 Difficulty: 4.30G
# New job received: 0x9893dc Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0xfe1684 Epoch: 486 Difficulty: 4.30G
# New job received: 0x878138 Epoch: 486 Difficulty: 4.30G
# New job received: 0x97a214 Epoch: 486 Difficulty: 4.30G
# New job received: 0x966882 Epoch: 486 Difficulty: 4.30G
# New job received: 0x044694 Epoch: 486 Difficulty: 4.30G
# New job received: 0xde9681 Epoch: 486 Difficulty: 4.30G
# New job received: 0xd94e5c Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x983be8 Epoch: 486 Difficulty: 4.30G
# New job received: 0x3dcadc Epoch: 486 Difficulty: 4.30G
# New job received: 0x7eae9b Epoch: 486 Difficulty: 4.30G
# New job received: 0x761872 Epoch: 486 Difficulty: 4.30G
# New job received: 0xaf44cd Epoch: 486 Difficulty: 4.30G
# New job received: 0x669de9 Epoch: 486 Difficulty: 4.30G
# New job received: 0x874f1e Epoch: 486 Difficulty: 4.30G
# New job received: 0x7ce5e2 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe155c3 Epoch: 486 Difficulty: 4.30G
# New job received: 0xc52af4 Epoch: 486 Difficulty: 4.30G
# New job received: 0x802e74 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x07e29b Epoch: 486 Difficulty: 4.30G
# New job received: 0x2751af Epoch: 486 Difficulty: 4.30G
# New job received: 0xf73109 Epoch: 486 Difficulty: 4.30G
# New job received: 0x886aa3 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa58b72 Epoch: 486 Difficulty: 4.30G
# New job received: 0xad8147 Epoch: 486 Difficulty: 4.30G
# New job received: 0x436758 Epoch: 486 Difficulty: 4.30G
# New job received: 0xabc8f5 Epoch: 486 Difficulty: 4.30G
# New job received: 0xf04838 Epoch: 486 Difficulty: 4.30G
# New job received: 0x59680f Epoch: 486 Difficulty: 4.30G
# New job received: 0x251dcc Epoch: 486 Difficulty: 4.30G
# ---------------------------------------------
# Statistics (02:55:02); Uptime: 0h 5m 0s
# Mining: Ethash
# Connected to: asia1.ethermine.org:4444
#
#       Name      Speed  Pool  Shares   Best    Eff.  Power  CCLK  MCLK  Core  Fan
#                  Mh/s  Mh/s  A/S/Hw  Share  Mh/s/W      W   MHz   MHz  Temp  Pct
# GPU 0 Tesla K80  1.28  0.00   0/0/0    0.0   0.014   91.8   562  2505    73  err
# ---------------------------
# Total            1.28  0.00   0/0/0    0.0   0.014   91.8
# ---------------------------------------------
# Average speed (15s): 1.28 Mh/s
# New job received: 0xc030da Epoch: 486 Difficulty: 4.30G
# New job received: 0x94b5eb Epoch: 486 Difficulty: 4.30G
# New job received: 0x8bf0bd Epoch: 486 Difficulty: 4.30G
# New job received: 0xaa1c7d Epoch: 486 Difficulty: 4.30G
# New job received: 0xe1592e Epoch: 486 Difficulty: 4.30G
# New job received: 0xa8357d Epoch: 486 Difficulty: 4.30G
# New job received: 0x8152b0 Epoch: 486 Difficulty: 4.30G
# New job received: 0x50056d Epoch: 486 Difficulty: 4.30G
# New job received: 0x4ef283 Epoch: 486 Difficulty: 4.30G
# New job received: 0x8a0d5f Epoch: 486 Difficulty: 4.30G
# New job received: 0x243bd2 Epoch: 486 Difficulty: 4.30G
# New job received: 0x73e43a Epoch: 486 Difficulty: 4.30G
# New job received: 0xca5849 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x392f84 Epoch: 486 Difficulty: 4.30G
# New job received: 0x36c352 Epoch: 486 Difficulty: 4.30G
# New job received: 0xadb6ab Epoch: 486 Difficulty: 4.30G
# New job received: 0x30f52b Epoch: 486 Difficulty: 4.30G
# New job received: 0x41ba67 Epoch: 486 Difficulty: 4.30G
# New job received: 0xb1f024 Epoch: 486 Difficulty: 4.30G
# New job received: 0x02dce8 Epoch: 486 Difficulty: 4.30G
# New job received: 0xf17d4d Epoch: 486 Difficulty: 4.30G
# New job received: 0xdab536 Epoch: 486 Difficulty: 4.30G
# New job received: 0x0fbfca Epoch: 486 Difficulty: 4.30G
# New job received: 0x2dc887 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe4e517 Epoch: 486 Difficulty: 4.30G
# New job received: 0x94cc20 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x6b1258 Epoch: 486 Difficulty: 4.30G
# New job received: 0x552cf0 Epoch: 486 Difficulty: 4.30G
# New job received: 0x7faecc Epoch: 486 Difficulty: 4.30G
# New job received: 0xe5d77f Epoch: 486 Difficulty: 4.30G
# New job received: 0x520336 Epoch: 486 Difficulty: 4.30G
# New job received: 0xc9f3c1 Epoch: 486 Difficulty: 4.30G
# New job received: 0x042ba9 Epoch: 486 Difficulty: 4.30G
# New job received: 0xb30331 Epoch: 486 Difficulty: 4.30G
# New job received: 0x8bca37 Epoch: 486 Difficulty: 4.30G
# New job received: 0xbc8899 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa54108 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa7aa75 Epoch: 486 Difficulty: 4.30G
# New job received: 0x32b574 Epoch: 486 Difficulty: 4.30G
# New job received: 0x712612 Epoch: 486 Difficulty: 4.30G
# New job received: 0xf231b3 Epoch: 486 Difficulty: 4.30G
# New job received: 0x6eec8f Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x2be42d Epoch: 486 Difficulty: 4.30G
# New job received: 0x33e24d Epoch: 486 Difficulty: 4.30G
# New job received: 0x2808b5 Epoch: 486 Difficulty: 4.30G
# New job received: 0x044f96 Epoch: 486 Difficulty: 4.30G
# New job received: 0x8f4567 Epoch: 486 Difficulty: 4.30G
# New job received: 0xf37ad4 Epoch: 486 Difficulty: 4.30G
# New job received: 0x522445 Epoch: 486 Difficulty: 4.30G
# New job received: 0xbe3e2f Epoch: 486 Difficulty: 4.30G
# New job received: 0x604719 Epoch: 486 Difficulty: 4.30G
# New job received: 0xab99f9 Epoch: 486 Difficulty: 4.30G
# New job received: 0xfe79fd Epoch: 486 Difficulty: 4.30G
# New job received: 0x9d7ccd Epoch: 486 Difficulty: 4.30G
# New job received: 0x8bd187 Epoch: 486 Difficulty: 4.30G
# New job received: 0x333920 Epoch: 486 Difficulty: 4.30G
# New job received: 0x576664 Epoch: 486 Difficulty: 4.30G
# New job received: 0x42f957 Epoch: 486 Difficulty: 4.30G
# ---------------------------------------------
# Statistics (02:56:02); Uptime: 0h 6m 0s
# Mining: Ethash
# Connected to: asia1.ethermine.org:4444
#
#       Name      Speed  Pool  Shares   Best    Eff.  Power  CCLK  MCLK  Core  Fan
#                  Mh/s  Mh/s  A/S/Hw  Share  Mh/s/W      W   MHz   MHz  Temp  Pct
# GPU 0 Tesla K80  1.28  0.00   0/0/0    0.0   0.014   91.8   562  2505    73  err
# ---------------------------
# Total            1.28  0.00   0/0/0    0.0   0.014   91.8
# ---------------------------------------------
# Average speed (15s): 1.28 Mh/s
# New job received: 0xe4fba7 Epoch: 486 Difficulty: 4.30G
# New job received: 0xc989e8 Epoch: 486 Difficulty: 4.30G
# New job received: 0x503280 Epoch: 486 Difficulty: 4.30G
# New job received: 0xdd446f Epoch: 486 Difficulty: 4.30G
# New job received: 0xfdc596 Epoch: 486 Difficulty: 4.30G
# New job received: 0x7334c9 Epoch: 486 Difficulty: 4.30G
# New job received: 0x97fce8 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe26428 Epoch: 486 Difficulty: 4.30G
# New job received: 0xd0abe5 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe694e6 Epoch: 486 Difficulty: 4.30G
# New job received: 0xcb416c Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x1cef2f Epoch: 486 Difficulty: 4.30G
# New job received: 0xd7a716 Epoch: 486 Difficulty: 4.30G
# New job received: 0xac8c46 Epoch: 486 Difficulty: 4.30G
# New job received: 0x7fef7a Epoch: 486 Difficulty: 4.30G
# New job received: 0xb3b263 Epoch: 486 Difficulty: 4.30G
# New job received: 0xb7bdf0 Epoch: 486 Difficulty: 4.30G
# New job received: 0x51aadc Epoch: 486 Difficulty: 4.30G
# New job received: 0x8a8703 Epoch: 486 Difficulty: 4.30G
# New job received: 0xb8625c Epoch: 486 Difficulty: 4.30G
# New job received: 0xbf2dd5 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x99e064 Epoch: 486 Difficulty: 4.30G
# New job received: 0x64e253 Epoch: 486 Difficulty: 4.30G
# New job received: 0x703724 Epoch: 486 Difficulty: 4.30G
# New job received: 0x71306f Epoch: 486 Difficulty: 4.30G
# New job received: 0xc48b13 Epoch: 486 Difficulty: 4.30G
# New job received: 0x2820c3 Epoch: 486 Difficulty: 4.30G
# New job received: 0x2f2faa Epoch: 486 Difficulty: 4.30G
# New job received: 0x8735a6 Epoch: 486 Difficulty: 4.30G
# New job received: 0xfd244a Epoch: 486 Difficulty: 4.30G
# New job received: 0xb5802c Epoch: 486 Difficulty: 4.30G
# New job received: 0xeba31f Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0xd709b6 Epoch: 486 Difficulty: 4.30G
# New job received: 0x0a642e Epoch: 486 Difficulty: 4.30G
# New job received: 0xcea1dc Epoch: 486 Difficulty: 4.30G
# New job received: 0xccdd33 Epoch: 486 Difficulty: 4.30G
# New job received: 0x79b68b Epoch: 486 Difficulty: 4.30G
# New job received: 0x088bea Epoch: 486 Difficulty: 4.30G
# New job received: 0xffac03 Epoch: 486 Difficulty: 4.30G
# New job received: 0x5870cf Epoch: 486 Difficulty: 4.30G
# ---------------------------------------------
# Statistics (02:57:02); Uptime: 0h 7m 0s
# Mining: Ethash
# Connected to: asia1.ethermine.org:4444
#
#       Name      Speed  Pool  Shares   Best    Eff.  Power  CCLK  MCLK  Core  Fan
#                  Mh/s  Mh/s  A/S/Hw  Share  Mh/s/W      W   MHz   MHz  Temp  Pct
# GPU 0 Tesla K80  1.28  0.00   0/0/0    0.0   0.014   91.8   562  2505    73  err
# ---------------------------
# Total            1.28  0.00   0/0/0    0.0   0.014   91.8
# ---------------------------------------------
# Average speed (15s): 1.28 Mh/s
# New job received: 0xbaff61 Epoch: 486 Difficulty: 4.30G
# New job received: 0xd017bb Epoch: 486 Difficulty: 4.30G
# New job received: 0xe38d4a Epoch: 486 Difficulty: 4.30G
# New job received: 0x823d76 Epoch: 486 Difficulty: 4.30G
# New job received: 0x2cf11a Epoch: 486 Difficulty: 4.30G
# New job received: 0x1d7f4f Epoch: 486 Difficulty: 4.30G
# New job received: 0xad6e9f Epoch: 486 Difficulty: 4.30G
# New job received: 0x7a5680 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe2eab0 Epoch: 486 Difficulty: 4.30G
# New job received: 0xb9ace9 Epoch: 486 Difficulty: 4.30G
# New job received: 0xf6e1a7 Epoch: 486 Difficulty: 4.30G
# New job received: 0xb7c313 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0xdb8203 Epoch: 486 Difficulty: 4.30G
# New job received: 0x565a56 Epoch: 486 Difficulty: 4.30G
# New job received: 0x6c547f Epoch: 486 Difficulty: 4.30G
# New job received: 0xdb583c Epoch: 486 Difficulty: 4.30G
# New job received: 0x7d65c5 Epoch: 486 Difficulty: 4.30G
# New job received: 0x6c08c8 Epoch: 486 Difficulty: 4.30G
# New job received: 0x879e91 Epoch: 486 Difficulty: 4.30G
# New job received: 0x081969 Epoch: 486 Difficulty: 4.30G
# New job received: 0xffa0ec Epoch: 486 Difficulty: 4.30G
# New job received: 0x0295b6 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe19c77 Epoch: 486 Difficulty: 4.30G
# New job received: 0x8054c3 Epoch: 486 Difficulty: 4.30G
# New job received: 0x9d9684 Epoch: 486 Difficulty: 4.30G
# New job received: 0x2e61f8 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x576ce8 Epoch: 486 Difficulty: 4.30G
# New job received: 0x330068 Epoch: 486 Difficulty: 4.30G
# New job received: 0xff760c Epoch: 486 Difficulty: 4.30G
# New job received: 0x7198c9 Epoch: 486 Difficulty: 4.30G
# New job received: 0xdab2a8 Epoch: 486 Difficulty: 4.30G
# New job received: 0x25b1ac Epoch: 486 Difficulty: 4.30G
# New job received: 0xcc9dc5 Epoch: 486 Difficulty: 4.30G
# New job received: 0x4aa68c Epoch: 486 Difficulty: 4.30G
# New job received: 0xf24284 Epoch: 486 Difficulty: 4.30G
# New job received: 0x874021 Epoch: 486 Difficulty: 4.30G
# New job received: 0x4f6a53 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x48a3bb Epoch: 486 Difficulty: 4.30G
# New job received: 0x852167 Epoch: 486 Difficulty: 4.30G
# New job received: 0x740d73 Epoch: 486 Difficulty: 4.30G
# New job received: 0x9a1014 Epoch: 486 Difficulty: 4.30G
# New job received: 0xfff26a Epoch: 486 Difficulty: 4.30G
# New job received: 0x54de95 Epoch: 486 Difficulty: 4.30G
# New job received: 0x97c378 Epoch: 486 Difficulty: 4.30G
# New job received: 0xedf326 Epoch: 486 Difficulty: 4.30G
# New job received: 0xde46f7 Epoch: 486 Difficulty: 4.30G
# New job received: 0x3ef27b Epoch: 486 Difficulty: 4.30G
# New job received: 0xa17279 Epoch: 486 Difficulty: 4.30G
# New job received: 0x38b5fe Epoch: 486 Difficulty: 4.30G
# New job received: 0x1308b3 Epoch: 486 Difficulty: 4.30G
# ---------------------------------------------
# Statistics (02:58:02); Uptime: 0h 8m 0s
# Mining: Ethash
# Connected to: asia1.ethermine.org:4444
#
#       Name      Speed  Pool  Shares   Best    Eff.  Power  CCLK  MCLK  Core  Fan
#                  Mh/s  Mh/s  A/S/Hw  Share  Mh/s/W      W   MHz   MHz  Temp  Pct
# GPU 0 Tesla K80  1.28  0.00   0/0/0    0.0   0.014   91.8   562  2505    73  err
# ---------------------------
# Total            1.28  0.00   0/0/0    0.0   0.014   91.8
# ---------------------------------------------
# Average speed (15s): 1.28 Mh/s
# New job received: 0x3fc46f Epoch: 486 Difficulty: 4.30G
# New job received: 0x0b4829 Epoch: 486 Difficulty: 4.30G
# New job received: 0x8b0c2b Epoch: 486 Difficulty: 4.30G
# New job received: 0x3da515 Epoch: 486 Difficulty: 4.30G
# New job received: 0xdd74ff Epoch: 486 Difficulty: 4.30G
# New job received: 0xb9ccfe Epoch: 486 Difficulty: 4.30G
# New job received: 0x537e99 Epoch: 486 Difficulty: 4.30G
# New job received: 0x6cb7b2 Epoch: 486 Difficulty: 4.30G
# New job received: 0x75bd8d Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x8ce702 Epoch: 486 Difficulty: 4.30G
# New job received: 0x3b5fb2 Epoch: 486 Difficulty: 4.30G
# New job received: 0x60b192 Epoch: 486 Difficulty: 4.30G
# New job received: 0x60c989 Epoch: 486 Difficulty: 4.30G
# New job received: 0x15de64 Epoch: 486 Difficulty: 4.30G
# New job received: 0x132627 Epoch: 486 Difficulty: 4.30G
# New job received: 0x0e6d13 Epoch: 486 Difficulty: 4.30G
# New job received: 0x8d7704 Epoch: 486 Difficulty: 4.30G
# New job received: 0xf40375 Epoch: 486 Difficulty: 4.30G
# New job received: 0xf9fa32 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0xeac54f Epoch: 486 Difficulty: 4.30G
# New job received: 0x2c18f5 Epoch: 486 Difficulty: 4.30G
# New job received: 0x33d426 Epoch: 486 Difficulty: 4.30G
# New job received: 0x7a8548 Epoch: 486 Difficulty: 4.30G
# New job received: 0x4c2250 Epoch: 486 Difficulty: 4.30G
# New job received: 0x20cb64 Epoch: 486 Difficulty: 4.30G
# New job received: 0x5b8798 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa74939 Epoch: 486 Difficulty: 4.30G
# New job received: 0x33ebfe Epoch: 486 Difficulty: 4.30G
# New job received: 0x6d7166 Epoch: 486 Difficulty: 4.30G
# New job received: 0x87c0ee Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0xca108f Epoch: 486 Difficulty: 4.30G
# New job received: 0x90629a Epoch: 486 Difficulty: 4.30G
# New job received: 0x18ab89 Epoch: 486 Difficulty: 4.30G
# New job received: 0xf548d3 Epoch: 486 Difficulty: 4.30G
# New job received: 0x0ce94e Epoch: 486 Difficulty: 4.30G
# New job received: 0x9cb5c6 Epoch: 486 Difficulty: 4.30G
# New job received: 0x7a3eb2 Epoch: 486 Difficulty: 4.30G
# New job received: 0x5c7cae Epoch: 486 Difficulty: 4.30G
# New job received: 0xe18501 Epoch: 486 Difficulty: 4.30G
# New job received: 0xf66ba6 Epoch: 486 Difficulty: 4.30G
# New job received: 0x8c02ed Epoch: 486 Difficulty: 4.30G
# ---------------------------------------------
# Statistics (02:59:02); Uptime: 0h 9m 0s
# Mining: Ethash
# Connected to: asia1.ethermine.org:4444
#
#       Name      Speed  Pool  Shares   Best    Eff.  Power  CCLK  MCLK  Core  Fan
#                  Mh/s  Mh/s  A/S/Hw  Share  Mh/s/W      W   MHz   MHz  Temp  Pct
# GPU 0 Tesla K80  1.28  0.00   0/0/0    0.0   0.014   92.0   562  2505    73  err
# ---------------------------
# Total            1.28  0.00   0/0/0    0.0   0.014   92.0
# ---------------------------------------------
# Average speed (15s): 1.28 Mh/s
# New job received: 0x9db656 Epoch: 486 Difficulty: 4.30G
# New job received: 0x71a0df Epoch: 486 Difficulty: 4.30G
# New job received: 0xbf12c8 Epoch: 486 Difficulty: 4.30G
# New job received: 0xd8dade Epoch: 486 Difficulty: 4.30G
# New job received: 0x3e5e58 Epoch: 486 Difficulty: 4.30G
# New job received: 0xc86e6f Epoch: 486 Difficulty: 4.30G
# New job received: 0xa72b11 Epoch: 486 Difficulty: 4.30G
# New job received: 0x1c817d Epoch: 486 Difficulty: 4.30G
# New job received: 0x67a6bd Epoch: 486 Difficulty: 4.30G
# New job received: 0x7df106 Epoch: 486 Difficulty: 4.30G
# New job received: 0xbfdce6 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0xaed1fa Epoch: 486 Difficulty: 4.30G
# New job received: 0x4ef42e Epoch: 486 Difficulty: 4.30G
# New job received: 0x776e48 Epoch: 486 Difficulty: 4.30G
# New job received: 0x204da1 Epoch: 486 Difficulty: 4.30G
# New job received: 0xb79ef8 Epoch: 486 Difficulty: 4.30G
# New job received: 0xf5db75 Epoch: 486 Difficulty: 4.30G
# New job received: 0xcdb9ed Epoch: 486 Difficulty: 4.30G
# New job received: 0x89b92d Epoch: 486 Difficulty: 4.30G
# New job received: 0x4fc889 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0xbdeafd Epoch: 486 Difficulty: 4.30G
# New job received: 0x5bdfa5 Epoch: 486 Difficulty: 4.30G
# New job received: 0x14dc18 Epoch: 486 Difficulty: 4.30G
# New job received: 0xb976ad Epoch: 486 Difficulty: 4.30G
# New job received: 0xf4a019 Epoch: 486 Difficulty: 4.30G
# New job received: 0x9ce79a Epoch: 486 Difficulty: 4.30G
# New job received: 0x36742e Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x863d3b Epoch: 486 Difficulty: 4.30G
# New job received: 0xd0a952 Epoch: 486 Difficulty: 4.30G
# New job received: 0x4456fc Epoch: 486 Difficulty: 4.30G
# New job received: 0x803b0c Epoch: 486 Difficulty: 4.30G
# New job received: 0x606233 Epoch: 486 Difficulty: 4.30G
# New job received: 0xc2736c Epoch: 486 Difficulty: 4.30G
# New job received: 0xe8bc68 Epoch: 486 Difficulty: 4.30G
# New job received: 0x4d682f Epoch: 486 Difficulty: 4.30G
# ---------------------------------------------
# Statistics (03:00:02); Uptime: 0h 10m 0s
# Mining: Ethash
# Connected to: asia1.ethermine.org:4444
#
#       Name      Speed  Pool  Shares   Best    Eff.  Power  CCLK  MCLK  Core  Fan
#                  Mh/s  Mh/s  A/S/Hw  Share  Mh/s/W      W   MHz   MHz  Temp  Pct
# GPU 0 Tesla K80  1.28  0.00   0/0/0    0.0   0.014   91.8   562  2505    73  err
# ---------------------------
# Total            1.28  0.00   0/0/0    0.0   0.014   91.8
# ---------------------------------------------
# Average speed (15s): 1.28 Mh/s
# New job received: 0x3e76ba Epoch: 486 Difficulty: 4.30G
# New job received: 0xcc18f3 Epoch: 486 Difficulty: 4.30G
# New job received: 0xfaeafd Epoch: 486 Difficulty: 4.30G
# New job received: 0x437e18 Epoch: 486 Difficulty: 4.30G
# New job received: 0x9a08b3 Epoch: 486 Difficulty: 4.30G
# New job received: 0xf4e4b9 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe07d8c Epoch: 486 Difficulty: 4.30G
# New job received: 0x9eb5f3 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa13a7e Epoch: 486 Difficulty: 4.30G
# New job received: 0x3c9bfc Epoch: 486 Difficulty: 4.30G
# New job received: 0x5633d1 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa7bd9a Epoch: 486 Difficulty: 4.30G
# New job received: 0x93c2b2 Epoch: 486 Difficulty: 4.30G
# New job received: 0x3dc7a9 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x2cd159 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa64598 Epoch: 486 Difficulty: 4.30G
# New job received: 0x9832e9 Epoch: 486 Difficulty: 4.30G
# New job received: 0x22fe64 Epoch: 486 Difficulty: 4.30G
# New job received: 0x01040b Epoch: 486 Difficulty: 4.30G
# New job received: 0x16f4b5 Epoch: 486 Difficulty: 4.30G
# New job received: 0x6e9635 Epoch: 486 Difficulty: 4.30G
# New job received: 0xddd6a0 Epoch: 486 Difficulty: 4.30G
# New job received: 0xc49c5d Epoch: 486 Difficulty: 4.30G
# New job received: 0xdfc87b Epoch: 486 Difficulty: 4.30G
# New job received: 0x1e3b92 Epoch: 486 Difficulty: 4.30G
# New job received: 0xf328af Epoch: 486 Difficulty: 4.30G
# New job received: 0x88ed0a Epoch: 486 Difficulty: 4.30G
# New job received: 0xbd57eb Epoch: 486 Difficulty: 4.30G
# New job received: 0x63e9e9 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x7f335d Epoch: 486 Difficulty: 4.30G
# New job received: 0x2cbad5 Epoch: 486 Difficulty: 4.30G
# New job received: 0x365519 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa6a784 Epoch: 486 Difficulty: 4.30G
# New job received: 0x0101ec Epoch: 486 Difficulty: 4.30G
# New job received: 0xe1778e Epoch: 486 Difficulty: 4.30G
# New job received: 0x00889b Epoch: 486 Difficulty: 4.30G
# New job received: 0x3a78a3 Epoch: 486 Difficulty: 4.30G
# New job received: 0x20496a Epoch: 486 Difficulty: 4.30G
# New job received: 0x34ad3d Epoch: 486 Difficulty: 4.30G
# New job received: 0x066f01 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa73eb9 Epoch: 486 Difficulty: 4.30G
# New job received: 0x25480e Epoch: 486 Difficulty: 4.30G
# New job received: 0xe71f7b Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0xde631e Epoch: 486 Difficulty: 4.30G
# New job received: 0x218058 Epoch: 486 Difficulty: 4.30G
# New job received: 0x62de7b Epoch: 486 Difficulty: 4.30G
# New job received: 0x2bca17 Epoch: 486 Difficulty: 4.30G
# New job received: 0xccf902 Epoch: 486 Difficulty: 4.30G
# New job received: 0x0a8cc8 Epoch: 486 Difficulty: 4.30G
# New job received: 0x063592 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe6b625 Epoch: 486 Difficulty: 4.30G
# New job received: 0xffdd8d Epoch: 486 Difficulty: 4.30G
# New job received: 0xd9d8a5 Epoch: 486 Difficulty: 4.30G
# ---------------------------------------------
# Statistics (03:01:02); Uptime: 0h 11m 0s
# Mining: Ethash
# Connected to: asia1.ethermine.org:4444
#
#       Name      Speed  Pool  Shares   Best    Eff.  Power  CCLK  MCLK  Core  Fan
#                  Mh/s  Mh/s  A/S/Hw  Share  Mh/s/W      W   MHz   MHz  Temp  Pct
# GPU 0 Tesla K80  1.28  0.00   0/0/0    0.0   0.014   91.9   562  2505    73  err
# ---------------------------
# Total            1.28  0.00   0/0/0    0.0   0.014   91.9
# ---------------------------------------------
# Average speed (15s): 1.28 Mh/s
# New job received: 0xc65f5e Epoch: 486 Difficulty: 4.30G
# New job received: 0x6a714f Epoch: 486 Difficulty: 4.30G
# New job received: 0x664b94 Epoch: 486 Difficulty: 4.30G
# New job received: 0x1b42aa Epoch: 486 Difficulty: 4.30G
# New job received: 0x9e4bcc Epoch: 486 Difficulty: 4.30G
# New job received: 0xd9d7bd Epoch: 486 Difficulty: 4.30G
# New job received: 0xccc7b5 Epoch: 486 Difficulty: 4.30G
# New job received: 0x9e0e93 Epoch: 486 Difficulty: 4.30G
# New job received: 0x751e9a Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x4d5481 Epoch: 486 Difficulty: 4.30G
# New job received: 0xdbc6a2 Epoch: 486 Difficulty: 4.30G
# New job received: 0x8f3724 Epoch: 486 Difficulty: 4.30G
# New job received: 0xfaafbc Epoch: 486 Difficulty: 4.30G
# New job received: 0x5788ac Epoch: 486 Difficulty: 4.30G
# New job received: 0xa815eb Epoch: 486 Difficulty: 4.30G
# New job received: 0x5f3db7 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe11b20 Epoch: 486 Difficulty: 4.30G
# New job received: 0xeea350 Epoch: 486 Difficulty: 4.30G
# New job received: 0x2c6bcc Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0xcddae6 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa1f03b Epoch: 486 Difficulty: 4.30G
# New job received: 0x9bc86f Epoch: 486 Difficulty: 4.30G
# New job received: 0x69bd01 Epoch: 486 Difficulty: 4.30G
# New job received: 0x0c8cc1 Epoch: 486 Difficulty: 4.30G
# New job received: 0x73c899 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa25017 Epoch: 486 Difficulty: 4.30G
# New job received: 0x03b3f1 Epoch: 486 Difficulty: 4.30G
# New job received: 0x9be4ce Epoch: 486 Difficulty: 4.30G
# New job received: 0xdecb2f Epoch: 486 Difficulty: 4.30G
# New job received: 0xb005f2 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa80523 Epoch: 486 Difficulty: 4.30G
# New job received: 0xc79e67 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x73953f Epoch: 486 Difficulty: 4.30G
# New job received: 0xa8a62c Epoch: 486 Difficulty: 4.30G
# New job received: 0x062443 Epoch: 486 Difficulty: 4.30G
# New job received: 0x13c9d7 Epoch: 486 Difficulty: 4.30G
# New job received: 0x1f8d30 Epoch: 486 Difficulty: 4.30G
# New job received: 0x7bfcc1 Epoch: 486 Difficulty: 4.30G
# New job received: 0x4e6380 Epoch: 486 Difficulty: 4.30G
# New job received: 0x708a73 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa38e93 Epoch: 486 Difficulty: 4.30G
# New job received: 0x879ce1 Epoch: 486 Difficulty: 4.30G
# New job received: 0x115822 Epoch: 486 Difficulty: 4.30G
# New job received: 0x4db2b4 Epoch: 486 Difficulty: 4.30G
# New job received: 0x261455 Epoch: 486 Difficulty: 4.30G
# ---------------------------------------------
# Statistics (03:02:02); Uptime: 0h 12m 0s
# Mining: Ethash
# Connected to: asia1.ethermine.org:4444
#
#       Name      Speed  Pool  Shares   Best    Eff.  Power  CCLK  MCLK  Core  Fan
#                  Mh/s  Mh/s  A/S/Hw  Share  Mh/s/W      W   MHz   MHz  Temp  Pct
# GPU 0 Tesla K80  1.28  0.00   0/0/0    0.0   0.014   91.9   562  2505    73  err
# ---------------------------
# Total            1.28  0.00   0/0/0    0.0   0.014   91.9
# ---------------------------------------------
# Average speed (15s): 1.28 Mh/s
# New job received: 0x006cfa Epoch: 486 Difficulty: 4.30G
# New job received: 0x7401ae Epoch: 486 Difficulty: 4.30G
# New job received: 0xabd15d Epoch: 486 Difficulty: 4.30G
# New job received: 0x9a774c Epoch: 486 Difficulty: 4.30G
# New job received: 0x1395d7 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa4854a Epoch: 486 Difficulty: 4.30G
# New job received: 0xb832e7 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe7bb6b Epoch: 486 Difficulty: 4.30G
# New job received: 0x8229ce Epoch: 486 Difficulty: 4.30G
# New job received: 0x33729e Epoch: 486 Difficulty: 4.30G
# New job received: 0x642bf9 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x043120 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa2865b Epoch: 486 Difficulty: 4.30G
# New job received: 0x3f03e1 Epoch: 486 Difficulty: 4.30G
# New job received: 0x31a78e Epoch: 486 Difficulty: 4.30G
# New job received: 0x518e22 Epoch: 486 Difficulty: 4.30G
# New job received: 0x9e09fc Epoch: 486 Difficulty: 4.30G
# New job received: 0xf55f51 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa8d88b Epoch: 486 Difficulty: 4.30G
# New job received: 0x29934f Epoch: 486 Difficulty: 4.30G
# New job received: 0x47024c Epoch: 486 Difficulty: 4.30G
# New job received: 0x74fa52 Epoch: 486 Difficulty: 4.30G
# New job received: 0x98ac4a Epoch: 486 Difficulty: 4.30G
# New job received: 0x944385 Epoch: 486 Difficulty: 4.30G
# New job received: 0xec9c6e Epoch: 486 Difficulty: 4.30G
# New job received: 0x9fbcb1 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0xe38065 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe157b9 Epoch: 486 Difficulty: 4.30G
# New job received: 0x10443a Epoch: 486 Difficulty: 4.30G
# New job received: 0x4b1412 Epoch: 486 Difficulty: 4.30G
# New job received: 0x6c73b5 Epoch: 486 Difficulty: 4.30G
# New job received: 0x9ee45f Epoch: 486 Difficulty: 4.30G
# New job received: 0xc42aeb Epoch: 486 Difficulty: 4.30G
# New job received: 0x1abe5a Epoch: 486 Difficulty: 4.30G
# New job received: 0xdc685f Epoch: 486 Difficulty: 4.30G
# New job received: 0xa7943f Epoch: 486 Difficulty: 4.30G
# New job received: 0xa78730 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x8c46d8 Epoch: 486 Difficulty: 4.30G
# New job received: 0x497db1 Epoch: 486 Difficulty: 4.30G
# New job received: 0xacd077 Epoch: 486 Difficulty: 4.30G
# New job received: 0x6a2d33 Epoch: 486 Difficulty: 4.30G
# New job received: 0x10f198 Epoch: 486 Difficulty: 4.30G
# New job received: 0x4332c4 Epoch: 486 Difficulty: 4.30G
# New job received: 0x02f69f Epoch: 486 Difficulty: 4.30G
# New job received: 0x6b7bd8 Epoch: 486 Difficulty: 4.30G
# New job received: 0x1fa8ba Epoch: 486 Difficulty: 4.30G
# New job received: 0xf0851b Epoch: 486 Difficulty: 4.30G
# New job received: 0x48c082 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa2b497 Epoch: 486 Difficulty: 4.30G
# New job received: 0xd07073 Epoch: 486 Difficulty: 4.30G
# ---------------------------------------------
# Statistics (03:03:02); Uptime: 0h 13m 0s
# Mining: Ethash
# Connected to: asia1.ethermine.org:4444
#
#       Name      Speed  Pool  Shares   Best    Eff.  Power  CCLK  MCLK  Core  Fan
#                  Mh/s  Mh/s  A/S/Hw  Share  Mh/s/W      W   MHz   MHz  Temp  Pct
# GPU 0 Tesla K80  1.28  0.00   0/0/0    0.0   0.014   91.8   562  2505    73  err
# ---------------------------
# Total            1.28  0.00   0/0/0    0.0   0.014   91.8
# ---------------------------------------------
# Average speed (15s): 1.28 Mh/s
# New job received: 0x2c8d9e Epoch: 486 Difficulty: 4.30G
# New job received: 0x5273e3 Epoch: 486 Difficulty: 4.30G
# New job received: 0x2ed47e Epoch: 486 Difficulty: 4.30G
# New job received: 0xa733e6 Epoch: 486 Difficulty: 4.30G
# New job received: 0x5b32ac Epoch: 486 Difficulty: 4.30G
# New job received: 0x87de91 Epoch: 486 Difficulty: 4.30G
# New job received: 0x3db8f1 Epoch: 486 Difficulty: 4.30G
# New job received: 0x21f427 Epoch: 486 Difficulty: 4.30G
# New job received: 0x509891 Epoch: 486 Difficulty: 4.30G
# New job received: 0x1fe281 Epoch: 486 Difficulty: 4.30G
# New job received: 0x890c0d Epoch: 486 Difficulty: 4.30G
# New job received: 0x0d4559 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa8b0d8 Epoch: 486 Difficulty: 4.30G
# New job received: 0x8dcba8 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x1a1e76 Epoch: 486 Difficulty: 4.30G
# New job received: 0xa7ff49 Epoch: 486 Difficulty: 4.30G
# New job received: 0x8da6d6 Epoch: 486 Difficulty: 4.30G
# New job received: 0x6c5179 Epoch: 486 Difficulty: 4.30G
# New job received: 0x12a2b1 Epoch: 486 Difficulty: 4.30G
# New job received: 0xcbd186 Epoch: 486 Difficulty: 4.30G
# New job received: 0xe17ccf Epoch: 486 Difficulty: 4.30G
# New job received: 0x3e7f1e Epoch: 486 Difficulty: 4.30G
# New job received: 0x3aa505 Epoch: 486 Difficulty: 4.30G
# New job received: 0x0e3275 Epoch: 486 Difficulty: 4.30G
# New job received: 0x55de91 Epoch: 486 Difficulty: 4.30G
# New job received: 0x9e7d96 Epoch: 486 Difficulty: 4.30G
# New job received: 0xb19e63 Epoch: 486 Difficulty: 4.30G
# New job received: 0x8e9160 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x897968 Epoch: 486 Difficulty: 4.30G
# New job received: 0x9c1177 Epoch: 486 Difficulty: 4.30G
# New job received: 0x68236b Epoch: 486 Difficulty: 4.30G
# New job received: 0xdb1e0e Epoch: 486 Difficulty: 4.30G
# New job received: 0x434feb Epoch: 486 Difficulty: 4.30G
# New job received: 0x20b8a2 Epoch: 486 Difficulty: 4.30G
# New job received: 0x4e132e Epoch: 486 Difficulty: 4.30G
# New job received: 0xbdaf01 Epoch: 486 Difficulty: 4.30G
# New job received: 0xd3cafb Epoch: 486 Difficulty: 4.30G
# New job received: 0xa88f2f Epoch: 486 Difficulty: 4.30G
# New job received: 0x6e02aa Epoch: 486 Difficulty: 4.30G
# New job received: 0x15b519 Epoch: 486 Difficulty: 4.30G
# Average speed (15s): 1.28 Mh/s
# New job received: 0x04d0f2 Epoch: 486 Difficulty: 4.30G
# New job received: 0x032969 Epoch: 486 Difficulty: 4.30G
# New job received: 0x4414b9 Epoch: 486 Difficulty: 4.30G
# New job received: 0x4a27e8 Epoch: 486 Difficulty: 4.30G
# New job received: 0x7301e8 Epoch: 486 Difficulty: 4.30G
# New job received: 0x98faf8 Epoch: 486 Difficulty: 4.30G
# New job received: 0x9ea0fe Epoch: 486 Difficulty: 4.30G
# New job received: 0x1cd38b Epoch: 486 Difficulty: 4.30G
# New job received: 0xea13ab Epoch: 486 Difficulty: 4.30G
# New job received: 0x4d96c5 Epoch: 486 Difficulty: 4.30G
# New job received: 0x9dc1f3 Epoch: 486 Difficulty: 4.30G

# %%
#@title **Colab Shutdown**

#@markdown To Kill NGROK Tunnel
NGROK = False #@param {type:'boolean'}

#@markdown To Sleep Colab
Sleep = True #@param {type:'boolean'}

if NGROK:
    ! killall ngrok

if Sleep:
    from time import sleep
    sleep(43200)
